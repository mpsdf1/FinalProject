# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.shapes import MSO_AUTO_SHAPE_TYPE
from pptx.dml.color import RGBColor

# Initialize presentation
prs = Presentation()
title_slide_layout = prs.slide_layouts[0]
content_slide_layout = prs.slide_layouts[1]

# Define slide content
slides_content = [
    {
        "title": "Predicting Student Dropout Using Deep Learning",
        "content": "Final Year Project Demonstration\nMarcello Pires dos Santos Ferreira\nBSc Computer Science"
    },
    {
        "title": "Project Overview",
        "content": "Goal: Predict students at risk of dropping out.\nDataset: Kaggle – 4,400+ records, 37 variables.\nStakeholders: Universities, policymakers, academic advisors."
    },
    {
        "title": "Dataset Description",
        "content": "• Demographics (age, gender, nationality)\n• Academic performance (grades, course progress)\n• Socioeconomic status (financial aid, parental education)\n• Target variable: Dropout vs. Graduate"
    },
    {
        "title": "Models Used",
        "content": "1. Random Forest Classifier\n2. Neural Network (2 hidden layers, dropout regularization)\nComparison to assess performance."
    },
    {
        "title": "Random Forest Results",
        "content": "• Accuracy: 73%\n• ROC-AUC: 0.72\n• Used SMOTE for class balancing\n• Precision and recall balanced across classes"
    },
    {
        "title": "Neural Network Results",
        "content": "• Accuracy: 79%\n• ROC-AUC: 0.748\n• F1-score (Graduate): 0.84\n• F1-score (Dropout): 0.68\n• Slight overfitting observed"
    },
    {
        "title": "Example Output",
        "content": "Confusion matrix and classification reports visualize student risk.\nCan be integrated into a dashboard for university use."
    },
    {
        "title": "Challenges & Future Work",
        "content": "• Address overfitting\n• Add attendance and engagement data\n• Explore ensemble or LSTM models\n• Improve dropout class recall"
    },
    {
        "title": "Thank You",
        "content": "This project shows how AI can help reduce dropout rates.\nThank you for watching!"
    }
]

# Add slides
for slide_data in slides_content:
    slide = prs.slides.add_slide(content_slide_layout)
    title = slide.shapes.title
    content = slide.placeholders[1]
    title.text = slide_data["title"]
    content.text = slide_data["content"]

# Save presentation
pptx_path = "/mnt/data/Predicting_Student_Dropout_Presentation.pptx"
prs.save(pptx_path)

pptx_path
